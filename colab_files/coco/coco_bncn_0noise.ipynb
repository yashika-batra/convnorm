# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 75.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 33.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 20.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 54.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_coco/coco_bnconv_colab.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 161: 100%|██████████| 24/24 [00:04<00:00,  4.99it/s,  [2816/3051 (92%)] Loss: 1.635573]
#
# ...
# Valid epoch 161: 100%|██████████| 4/4 [00:00<00:00,  5.53it/s]
#
# ...
# Test epoch 161: 100%|██████████| 34/34 [00:02<00:00, 14.51it/s]
# INFO:trainer:    epoch          : 161
# INFO:trainer:    loss           : 1.5752439200878143
# INFO:trainer:    my_metric      : 0.4339862003504673
# INFO:trainer:    my_metric2     : 0.9112788405373832
# INFO:trainer:    learning rate  : [3.906250000000001e-07, 3.906250000000001e-07, 3.906250000000001e-07, 3.906250000000001e-07]
# INFO:trainer:    val_loss       : 2.417369842529297
# INFO:trainer:    val_my_metric  : 0.21250000000000002
# INFO:trainer:    val_my_metric2 : 0.7075
# INFO:trainer:    test_loss      : 1.6089205496451433
# INFO:trainer:    test_my_metric : 0.4270200387847446
# INFO:trainer:    test_my_metric2: 0.9045927601809955
# one done
# ...
