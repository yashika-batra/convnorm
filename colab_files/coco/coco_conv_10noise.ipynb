# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 35.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 23.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 42.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_coco/coco_conv_colab_10.json
# Out:
# Streaming output truncated to the last 5000 lines.
# INFO:trainer:    val_my_metric  : 0.2275
# INFO:trainer:    val_my_metric2 : 0.68875
# INFO:trainer:    test_loss      : 1.742402732372284
# INFO:trainer:    test_my_metric : 0.3863186813186813
# INFO:trainer:    test_my_metric2: 0.8638299935358759
# INFO:trainer:Saving current model: current model save at: saved/models/ExperimentCOCODataLoaderresnet18-num_classes-10-norm_layer_type-no-conv_layer_type-prec_conv-linear_layer_type-linear-activation_layer_type-relu-Sym-0.1-Seed=12/1205_120759/model_epoch_160.pth ...
# ...
# Train epoch 161: 100%|██████████| 24/24 [00:04<00:00,  5.31it/s,  [2816/3051 (92%)] Loss: 1.673892]
#
# ...
# Valid epoch 161: 100%|██████████| 4/4 [00:00<00:00,  5.98it/s]
#
# ...
# Test epoch 161: 100%|██████████| 34/34 [00:02<00:00, 15.67it/s]
# one done
# INFO:trainer:    epoch          : 161
# INFO:trainer:    loss           : 1.7118315647045772
# INFO:trainer:    my_metric      : 0.3834787529205608
# ...
