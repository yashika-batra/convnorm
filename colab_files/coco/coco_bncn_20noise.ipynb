# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.7/586.7 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 33.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 25.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 17.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 41.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_coco/coco_bnconv_colab_20.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 161: 100%|██████████| 24/24 [00:05<00:00,  4.58it/s,  [2816/3051 (92%)] Loss: 1.784853]
#
# ...
# Valid epoch 161: 100%|██████████| 4/4 [00:00<00:00,  9.07it/s]
#
# ...
# Test epoch 161: 100%|██████████| 34/34 [00:01<00:00, 19.84it/s]
# one done
# INFO:trainer:    epoch          : 161
# INFO:trainer:    loss           : 1.777755583326022
# INFO:trainer:    my_metric      : 0.37319594528816197
# INFO:trainer:    my_metric2     : 0.8496337130062305
# INFO:trainer:    learning rate  : [3.906250000000001e-07, 3.906250000000001e-07, 3.906250000000001e-07, 3.906250000000001e-07]
# INFO:trainer:    val_loss       : 2.3821234107017517
# INFO:trainer:    val_my_metric  : 0.19875
# INFO:trainer:    val_my_metric2 : 0.6825000000000001
# INFO:trainer:    test_loss      : 1.825673320714165
# INFO:trainer:    test_my_metric : 0.35958306399482876
# INFO:trainer:    test_my_metric2: 0.8407401422107303
# ...
