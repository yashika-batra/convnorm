# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 25.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 30.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 44.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_cifar10/cifar10_bnconv_colab_10.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 96:  94%|█████████▎| 366/391 [00:58<00:03,  6.57it/s,  [46464/50000 (93%)] Loss: 0.026634]
# ...
# ...
# Valid epoch 100: 100%|██████████| 50/50 [00:02<00:00, 18.27it/s]
#
# ...
# Test epoch 100: 100%|██████████| 100/100 [00:04<00:00, 21.79it/s]
# one done
# INFO:trainer:    epoch          : 100
# INFO:trainer:    loss           : 0.0398149365187644
# INFO:trainer:    my_metric      : 0.989030530690537
# INFO:trainer:    my_metric2     : 0.9999600383631714
# INFO:trainer:    learning rate  : [0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002]
# INFO:trainer:    val_loss       : 2.0240664052963258
# INFO:trainer:    val_my_metric  : 0.8231999999999999
# INFO:trainer:    val_my_metric2 : 0.9368000000000002
# INFO:trainer:    test_loss      : 1.819318699836731
# INFO:trainer:    test_my_metric : 0.6710999999999997
# INFO:trainer:    test_my_metric2: 0.9434999999999999
# ...
