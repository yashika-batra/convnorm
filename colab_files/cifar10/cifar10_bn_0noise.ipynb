# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install comet_ml

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_cifar10/cifar10_bn_colab.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 96:  90%|█████████ | 353/391 [00:44<00:04,  7.93it/s,  [45056/50000 (90%)] Loss: 0.000297]
# ...
# ...
# Valid epoch 100: 100%|██████████| 50/50 [00:02<00:00, 21.41it/s]
#
# ...
# Test epoch 100: 100%|██████████| 100/100 [00:03<00:00, 25.95it/s]
# one done
# INFO:trainer:    epoch          : 100
# INFO:trainer:    loss           : 0.0022751668336294484
# INFO:trainer:    my_metric      : 0.9997602301790282
# INFO:trainer:    my_metric2     : 1.0
# INFO:trainer:    learning rate  : [0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002]
# INFO:trainer:    val_loss       : 0.0007518332477775403
# INFO:trainer:    val_my_metric  : 0.9997999999999999
# INFO:trainer:    val_my_metric2 : 1.0
# INFO:trainer:    test_loss      : 0.25842023520730434
# INFO:trainer:    test_my_metric : 0.9430000000000003
# INFO:trainer:    test_my_metric2: 0.9968999999999995
# ...
