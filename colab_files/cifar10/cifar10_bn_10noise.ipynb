# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 33.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 19.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 37.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_cifar10/cifar10_bn_colab_10.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 95: 100%|██████████| 391/391 [00:33<00:00, 11.59it/s,  [49280/50000 (99%)] Loss: 0.006208]
#
# ...
# Valid epoch 95:  38%|███▊      | 19/50 [00:01<00:01, 22.17it/s]
# ...
# ...
# Valid epoch 100: 100%|██████████| 50/50 [00:02<00:00, 24.39it/s]
#
# ...
# Test epoch 100: 100%|██████████| 100/100 [00:04<00:00, 21.41it/s]
# INFO:trainer:    epoch          : 100
# INFO:trainer:    loss           : 0.009555224076602989
# INFO:trainer:    my_metric      : 0.9979299872122762
# INFO:trainer:    my_metric2     : 1.0
# INFO:trainer:    learning rate  : [0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002]
# INFO:trainer:    val_loss       : 2.2246408963203432
# INFO:trainer:    val_my_metric  : 0.8258
# INFO:trainer:    val_my_metric2 : 0.9406
# INFO:trainer:    test_loss      : 0.6437879557907581
# INFO:trainer:    test_my_metric : 0.8798999999999997
# INFO:trainer:    test_my_metric2: 0.9877999999999997
# ...
