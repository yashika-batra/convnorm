# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 9.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 73.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 54.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_cifar10/cifar10_conv_colab_20.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 96: 100%|██████████| 391/391 [02:37<00:00,  2.49it/s,  [49280/50000 (99%)] Loss: 0.090465]
#
# ...
# Valid epoch 96: 100%|██████████| 50/50 [00:06<00:00,  8.21it/s]
#
# ...
# Test epoch 96: 100%|██████████| 100/100 [00:10<00:00,  9.41it/s]
# one done
# INFO:trainer:    epoch          : 96
# INFO:trainer:    loss           : 0.06770766248731204
# INFO:trainer:    my_metric      : 0.9798073849104859
# INFO:trainer:    my_metric2     : 0.999940057544757
# INFO:trainer:    learning rate  : [0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002]
# INFO:trainer:    val_loss       : 3.4112371301651
# INFO:trainer:    val_my_metric  : 0.6809999999999998
# INFO:trainer:    val_my_metric2 : 0.8772000000000003
# INFO:trainer:    test_loss      : 1.9986424899101258
# INFO:trainer:    test_my_metric : 0.6206999999999999
# INFO:trainer:    test_my_metric2: 0.9218
# ...
