# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 7.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 25.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 22.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 8.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 32.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_cifar10/cifar10_bnconv_colab_20.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 96:  96%|█████████▌| 376/391 [01:02<00:02,  6.43it/s,  [47872/50000 (96%)] Loss: 0.038888]
# ...
# ...
# Valid epoch 100: 100%|██████████| 50/50 [00:02<00:00, 17.05it/s]
#
# ...
# Test epoch 100: 100%|██████████| 100/100 [00:05<00:00, 19.38it/s]
# one done
# INFO:trainer:    epoch          : 100
# INFO:trainer:    loss           : 0.061676416872426525
# INFO:trainer:    my_metric      : 0.9816855818414323
# INFO:trainer:    my_metric2     : 0.9999000959079284
# INFO:trainer:    learning rate  : [0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002]
# INFO:trainer:    val_loss       : 3.53262939453125
# INFO:trainer:    val_my_metric  : 0.6816
# INFO:trainer:    val_my_metric2 : 0.8783999999999997
# INFO:trainer:    test_loss      : 2.0812983787059784
# INFO:trainer:    test_my_metric : 0.6175
# INFO:trainer:    test_my_metric2: 0.9214
# ...
