# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install comet_ml
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.4/586.4 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.8/252.8 kB 28.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.9/137.9 kB 18.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 512.2/512.2 kB 50.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: websocket-client
#     Found existing installation: websocket-client 1.6.4
#     Uninstalling websocket-client-1.6.4:
#       Successfully uninstalled websocket-client-1.6.4
#   Attempting uninstall: python-box
#     Found existing installation: python-box 7.1.1
#     Uninstalling python-box-7.1.1:
#       Successfully uninstalled python-box-7.1.1
# ...

# %%
# !python3 /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/train.py -c /content/drive/MyDrive/F23/10617/10617_FinalReport/ConvNorm-yb/config_cifar10/cifar10_bn_colab_20.json
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# Train epoch 95:  95%|█████████▌| 373/391 [00:33<00:01, 10.21it/s,  [47872/50000 (96%)] Loss: 0.013945]
# ...
# ...
# Valid epoch 100: 100%|██████████| 50/50 [00:03<00:00, 15.89it/s]
#
# ...
# Test epoch 100: 100%|██████████| 100/100 [00:04<00:00, 20.16it/s]
# INFO:trainer:    epoch          : 100
# INFO:trainer:    loss           : 0.019734089449167137
# INFO:trainer:    my_metric      : 0.9951007033248083
# INFO:trainer:    my_metric2     : 0.9999600383631714
# INFO:trainer:    learning rate  : [0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002, 0.0010000000000000002]
# INFO:trainer:    val_loss       : 3.9540312576293943
# INFO:trainer:    val_my_metric  : 0.6829999999999998
# INFO:trainer:    val_my_metric2 : 0.8879999999999998
# INFO:trainer:    test_loss      : 0.9517768353223801
# INFO:trainer:    test_my_metric : 0.8155999999999999
# INFO:trainer:    test_my_metric2: 0.9756999999999997
# one done
# ...
